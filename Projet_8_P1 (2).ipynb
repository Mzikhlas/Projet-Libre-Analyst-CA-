# %% [markdown]
# -----------------------------------------

# %% [markdown]
# # Analyses des ventes de l'Entreprise Leasing_Car

# %%
#Import des principales librairies Python
import pandas as pd
import seaborn as sns
import datetime as dt

import numpy as np 
import matplotlib as plt
import matplotlib.pyplot as plt

# %%
#Chargement du dataset 'test_data_location_voiture.csv'
data = pd.read_csv('data_loca_voit.csv')
data.head(40)
# Out:
#           DATE  Num-CDE  CLIENT_ID SEX  BIRTH  ID_PROD PRICE_mensuel  \
# 0   2017-01-12   602709      80033   F   1989   274745        193,48
# 1   2020-10-15   750103     175333   M   1961   194675        232,42
# 2   2020-10-14   752849     140344   M   1979   165540        422,17
# 3   2020-10-14   762646     165402   M   1965   192734        423,33
# 4   2020-10-14   766855     207795   M   1965   277795        236,19
# 5   2020-10-14   749531     137352   M   1960   192994        351,24
# 6   2020-10-14   752966     176284   M   1969    15171        352,69
# 7   2020-10-13   753517     151590   M   1973   126927         465,3
# 8   2020-10-13   762947     140344   M   1963   194695        321,71
# 9   2020-10-13   766274     152955   M   1981   194695        239,51
# 10  2020-10-13   768203     133666   M   1995   194805        335,42
# 11  2020-10-13   770132     163072   M   1974   194671        388,26
# 12  2020-10-13   764231     161606   M   1965    85049        239,74
# 13  2020-10-12   757586     133666   M   1965   193150        257,65
# 14  2020-10-12   772236     150813   M   1986   196569        478,74
# 15  2020-10-12   774052     161606   M   1965   260976        256,07
# 16  2020-10-12   774165     151590   F   1986   127697        395,61
# 17  2020-10-12   768037     175333   M   1960   194698        381,69
# 18  2020-10-12   767234     163072   M   1979   165567        279,64
# 19  2020-10-12   772196     151590   M   1961    85506        362,05
# 20  2020-10-11   763457     156370   M   1964    14926       2020,79
# 21  2020-10-11   738749     154277   M   2001   231902        254,72
# 22  2020-10-11   773579     161606   F   1965   234001        267,57
# 23  2020-10-11   758572     152955   M   1965   234344        198,01
# 24  2020-10-15   751361     137352   M   1977   194695        516,83
# 25  2020-10-11   765109     163534   M   1987    14935         590,9
# 26  2020-10-15   767030     150813   M   1960   194699        298,26
# 27  2020-10-15   755279     155250   F   1978    14531         405,4
# 28  2020-10-21   751856     207795   M   1975   276590         374,1
# 29  2020-10-21   763699     130805   M   1968   194697        444,27
# 30  2020-10-21   736301     133666   M   1978    32947        493,34
# 31  2020-10-21   755489     223829   F   1953   194751        297,28
# 32  2020-10-20   758808     203910   M   1978   194692        401,04
# 33  2020-10-20   756171     175333   M   1965   194700        284,85
# 34  2020-10-20   730754     161361   M   1965   164679        279,03
# 35  2020-10-20   753548     176284   F   1959    14197         263,9
# 36  2020-10-19   719244     133666   M   1971   294559        824,12
# 37  2020-10-19   741678     176284   M   1967   165609        250,88
# 38  2020-10-19   730726     161361   M   1965   164684        446,83
# 39  2020-10-19   760395     205533   M   1973    14007        477,91
#
#      Durée total  CATEG
# 0             49      0
# 1             31      0
# 2             31      0
# 3             31      0
# 4             43      0
# 5             43      0
# 6             31      0
# 7             31      0
# 8             43      0
# 9             43      0
# 10            37      0
# 11            19      0
# 12            43      0
# 13            37      0
# 14            34      0
# 15            43      0
# 16            31      0
# 17            31      0
# 18            55      0
# 19            31      0
# 20            13      0
# 21            43      0
# 22            43      0
# 23            28      0
# 24            27      0
# 25            22      0
# 26            55      0
# 27            31      0
# 28            43      0
# 29            31      0
# 30            37      0
# 31            55      0
# 32            22      0
# 33            31      0
# 34            31      0
# 35            31      0
# 36            37      0
# 37            31      0
# 38            31      0
# 39            31      0

# %% [markdown]
# # Nettoyage des données

# %% [markdown]
# ## Analyse des données manquantes

# %%
# Dénombrement des valeurs manquantes
data.isna().sum()
# Out:
# DATE             0
# Num-CDE          0
# CLIENT_ID        0
# SEX              0
# BIRTH            0
# ID_PROD          0
# PRICE_mensuel    0
#  Durée total     0
# CATEG            0
# dtype: int64

# %% [markdown]
# Le fichier ne présente pas de données manquantes

# %% [markdown]
# ## Analyse des données dupliquées

# %%
data.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 6937    False
# 6938    False
# 6939    False
# 6940    False
# 6941    False
# Length: 6942, dtype: bool

# %%
#taille
data.shape
# Out:
# (6942, 9)

# %% [markdown]
# ## Analyse des types

# %%
print(data.dtypes)
# Out:
# DATE             object
# Num-CDE           int64
# CLIENT_ID         int64
# SEX              object
# BIRTH             int64
# ID_PROD           int64
# PRICE_mensuel    object
#  Durée total      int64
# CATEG             int64
# dtype: object

# %% [markdown]
# On remarque que toutes les variables sont considérées comme des objets. On peut transformer la variable 'date' en type 'datetime'.

# %% [markdown]
# La variable 'sex' apparaît comme un objet, il peut être plus intéressant de changer ce type en variable catégorielle.

# %%
# system libraries
import warnings
warnings.filterwarnings('ignore')
warnings.simplefilter(action='ignore', category=FutureWarning)

data['DATE'] = pd.to_datetime(data['DATE'])

# %%
data['SEX'] = data['SEX'].astype('category')

# %%
print(data.dtypes)
# Out:
# DATE             datetime64[ns]
# Num-CDE                   int64
# CLIENT_ID                 int64
# SEX                    category
# BIRTH                     int64
# ID_PROD                   int64
# PRICE_mensuel            object
#  Durée total              int64
# CATEG                     int64
# dtype: object

# %%
#Il serait plus intéressant de modifier le type de la colonne 'categ' en une valeur catégorielle.
data['CATEG'] = data['CATEG'].astype('category')
data.dtypes
# Out:
# DATE             datetime64[ns]
# Num-CDE                   int64
# CLIENT_ID                 int64
# SEX                    category
# BIRTH                     int64
# ID_PROD                   int64
# PRICE_mensuel            object
#  Durée total              int64
# CATEG                  category
# dtype: object

# %%
#Une fois cette transformation faite, il est plus simple d'organiser les données par ordre chronologique.
data = data.sort_values('DATE')
data = data.set_index('DATE')
print(data.head())
# Out:
#             Num-CDE  CLIENT_ID SEX  BIRTH  ID_PROD PRICE_mensuel  \
# DATE
# 2017-01-12   602709      80033   F   1989   274745        193,48
# 2017-03-12   600938     135383   M   1968   290426        553,92
# 2017-03-12   607529     162349   F   1970   216952        229,21
# 2017-03-12   603512      80033   M   1984   290425        260,06
# 2017-03-12   602701      80033   F   1983   274745        184,65
#
#              Durée total CATEG
# DATE
# 2017-01-12            49     0
# 2017-03-12            28     0
# 2017-03-12            35     0
# 2017-03-12            22     0
# 2017-03-12            49     0

# %%
#On peut ainsi classer les produits par ordre de catégorie.
data= data.sort_values('CATEG')
print(data)
# Out:
#             Num-CDE  CLIENT_ID SEX  BIRTH  ID_PROD PRICE_mensuel  \
# DATE
# 2017-01-12   602709      80033   F   1989   274745        193,48
# 2020-10-15   755279     155250   F   1978    14531         405,4
# 2020-10-14   752849     140344   M   1979   165540        422,17
# 2020-10-14   762646     165402   M   1965   192734        423,33
# 2020-10-14   766855     207795   M   1965   277795        236,19
# ...             ...        ...  ..    ...      ...           ...
# 2020-08-11   751324     151590   M   1966    84897        421,37
# 2019-02-20   667025     151590   M   1967   229303        475,56
# 2021-04-03   770234     151590   M   1971    86124         806,4
# 2020-05-21   702311     156075   F   1989   294521        782,85
# 2019-07-05   694771     169344   F   1982   275708        386,25
#
#              Durée total CATEG
# DATE
# 2017-01-12            49     0
# 2020-10-15            31     0
# 2020-10-14            31     0
# 2020-10-14            31     0
# 2020-10-14            43     0
# ...                  ...   ...
# 2020-08-11            31     1
# 2019-02-20            35     1
# 2021-04-03            19     1
# 2020-05-21            31     1
# 2019-07-05            31     1
#
# [6942 rows x 8 columns]

# %%
# Reset les index pour pas les dupliquer et rename_axis pour éviter que les noms de colonnes soient au dessus des autres.
data.rename_axis(None,axis=1)
data.reset_index(inplace= True)
data.head()
# Out:
#         DATE  Num-CDE  CLIENT_ID SEX  BIRTH  ID_PROD PRICE_mensuel  \
# 0 2017-01-12   602709      80033   F   1989   274745        193,48
# 1 2020-10-15   755279     155250   F   1978    14531         405,4
# 2 2020-10-14   752849     140344   M   1979   165540        422,17
# 3 2020-10-14   762646     165402   M   1965   192734        423,33
# 4 2020-10-14   766855     207795   M   1965   277795        236,19
#
#     Durée total CATEG
# 0            49     0
# 1            31     0
# 2            31     0
# 3            31     0
# 4            43     0

# %% [markdown]
# # Enregistrements de fichiers nettoyé

# %%
#Une fois le nettoyage des fichiers terminés, on les enregistre en nouveau fichier csv pour l'étape d'analyse qui suit cette partie
data.to_csv("data_loca_voit.csv",index = False)
